# %%
import numpy as np
#攻击者可以指定的输入，这里还是以下面的明文为例
print("请输入待加密明文：") #明文0123456789abcdeffedcba9876543210  默认密钥0f1571c947d9e8590cb7add6af7f6798
a=input('')
lenth=int(len(a)/2)
if(lenth!=16):
   print('输入长度不为16字节，请重新输入')
temp=[0 for i in range(lenth)]  #临时保存整形明文数组
for i in range(lenth):
    temp[i]=int(a[i*2:i*2+2],16)
# Out:
# 请输入待加密明文：
# 0123456789abcdeffedcba9876543210

# %%
byte=np.array([

])

# %%
target=[0x55, 0x3b, 0x81, 0xd1, 0x42, 0x84, 0xd9, 0x8, 0xff, 0x26, 0xc7, 0xfb, 0x2f, 0xa4, 0x19, 0xd0] #攻击者所能看到的net1的输出

# %%
#尝试根据输入和输出进行爆破，假设攻击者已知net1的组成，因此攻击者将其归为2个异或的秘密字节的爆破。
k=15 #对应0-16的明文字节
num=0
for i in range(256):
    for j in range(256):
        if byte[temp[k]^i]^j==target[k]:
            num=num+1
            print('得出的可能组:(%d,%d)'%(i,j))
print('第%d个字节有%d个可行组'%(k,num))
# Out:
# 得出的可能组:(0,26)
# 得出的可能组:(1,82)
# 得出的可能组:(2,25)
# 得出的可能组:(3,173)
# 得出的可能组:(4,42)
# 得出的可能组:(5,137)
# 得出的可能组:(6,151)
# 得出的可能组:(7,32)
# 得出的可能组:(8,125)
# 得出的可能组:(9,4)
# 得出的可能组:(10,114)
# 得出的可能组:(11,127)
# 得出的可能组:(12,76)
# 得出的可能组:(13,116)
# 得出的可能组:(14,162)
# 得出的可能组:(15,16)
# 得出的可能组:(16,179)
# 得出的可能组:(17,172)
# 得出的可能组:(18,167)
# 得出的可能组:(19,171)
# 得出的可能组:(20,34)
# 得出的可能组:(21,187)
# 得出的可能组:(22,191)
# 得出的可能组:(23,21)
# 得出的可能组:(24,224)
# 得出的可能组:(25,209)
# 得出的可能组:(26,183)
# 得出的可能组:(27,251)
# 得出的可能组:(28,46)
# 得出的可能组:(29,7)
# 得出的可能组:(30,123)
# 得出的可能组:(31,166)
# 得出的可能组:(32,212)
# 得出的可能组:(33,23)
# 得出的可能组:(34,243)
# 得出的可能组:(35,19)
# 得出的可能组:(36,200)
# 得出的可能组:(37,70)
# 得出的可能组:(38,213)
# 得出的可能组:(39,74)
# 得出的可能组:(40,215)
# 得出的可能组:(41,194)
# 得出的可能组:(42,80)
# 得出的可能组:(43,50)
# 得出的可能组:(44,59)
# 得出的可能组:(45,247)
# 得出的可能组:(46,98)
# 得出的可能组:(47,165)
# 得出的可能组:(48,103)
# 得出的可能组:(49,45)
# 得出的可能组:(50,67)
# 得出的可能组:(51,246)
# 得出的可能组:(52,230)
# 得出的可能组:(53,239)
# 得出的可能组:(54,39)
# 得出的可能组:(55,28)
# 得出的可能组:(56,228)
# ...
